# %% [markdown]
# Given:
# model data of 34 species + ODE with 1 unknown h_10_TPplus

# %%
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
import tensorflow as tf

import models

# %%
data = sio.loadmat("../../data/data_case_3.mat")
t_test = data["t"]
u_test = data["Y"] # scaling?

#name_list = ['TF','VII', 'TF:VII', 'VIIa', 'TF:VIIa', 'IX', 'IXa', 'IXm', 'IXam',
#'X', 'Xa', 'Xm', 'Xam', 'II', 'IIa', 'IIm', 'IIam', 'PL', 'AP', 'VIII', 'VIIIa', 'VIIIm',
#'VIIIam', 'VIIIam:IXam', 'V', 'Va', 'Vm', 'Vam', 'Xam:Vam', 'I', 'Ia', 'TFPI', 'Xa:TFPI', 'ATIII']

TIM = 1800
NDM = [0.025, 10.0, 0.005, 10.0, 0.005, 90.0, 90.0, 10.0, 10.0, 170.0,
       170.0, 10.0, 10.0, 1400.0, 1400.0, 10.0, 10.0, 10.0, 10.0,
       0.7, 0.7, 0.7, 0.7, 0.7, 20.0, 20.0, 10.0, 10.0, 10.0, 7000.0,
       7000.0, 2.5, 2.5, 3400.0] #nM

exp_data_1 = np.loadtxt("../../data/exp_data_case_3.dat").T
t_exp_1 = exp_data_1[0]
u_exp_1 = exp_data_1[1]

plt.plot(t_test * TIM, (u_test[:, 14] * NDM[14] + u_test[:, 16] * NDM[16]) * 1e-9, 'b', label='Model(No Inh)')
plt.plot(t_exp_1, u_exp_1, 'bo', markerfacecolor='w', label='Exp')
plt.show()

# %%
np.max(data["Y"], axis=0)
# Out:
# array([1.00000000e+00, 1.00000000e+00, 4.54258697e+00, 5.41050264e-01,
#        1.29888545e-01, 1.00000000e+00, 1.00000000e-04, 8.99075842e+00,
#        8.99157588e-04, 1.00000000e+00, 6.52850980e-04, 1.69286597e+01,
#        2.63365081e+00, 1.00000000e+00, 1.19242711e-02, 1.35988619e+02,
#        5.67362069e+01, 1.00000000e+00, 1.00010020e+00, 1.00000000e+00,
#        1.00000000e-04, 9.98889639e-01, 9.96740400e-01, 7.49224388e-03,
#        1.00000000e+00, 1.07688723e-04, 1.99890385e+00, 1.94999777e+00,
#        1.96262243e+00, 1.00000000e+00, 1.00010002e+00, 1.00000000e+00,
#        9.95287924e-01, 1.00000000e+00])

# %%
plt.plot(t_test * TIM, u_test)
plt.show()

# %%
scale = np.array(
    [1, 1, 5, 0.5, 0.1, 1, 0.0001, 10, 0.001, 1, \
     0.001, 10, 2, 1, 0.01, 100, 100, 1, 1, 1, \
    0.0001, 1, 1, 0.01, 1, 0.0001, 1, 1, 1, 1, \
    1, 1, 1, 1]
).reshape([-1])

u_test = u_test / scale

plt.plot(t_test * TIM, u_test)
plt.show()

# %%
plt.plot(t_test * TIM, u_test[:, 10], label='u10')
plt.plot(t_test * TIM, u_test[:, 31], label='u31')
plt.plot(t_test * TIM, u_test[:, 32], label='u32')
plt.legend()
plt.show()

# %%
t_train = t_test[::20][5:, ] # discard first 5 points
u_train = u_test[::20][5:, ]
f_train = np.zeros_like(u_train)

model = models.PINN(TIM, NDM, scale, eps=1e-6)

# %%
loss = model.train(t_train, f_train, t_train, u_train, eps=1e-7, niter=200000)
# print total loss, data loss, ode loss, eq10_loss,eq31_loss, eq32_loss
# Out:
# 0 1.7255377e-06 1.7101853e-06 0.15352395 64569.2 0.07719933 0.07631817
# 1000 2.0793286e-06 2.0645728e-06 0.1475584 74405.06 0.07428673 0.073264234
# 2000 2.0042232e-06 1.9886297e-06 0.15593475 82203.72 0.0784524 0.077474125
# 3000 2.2688304e-05 2.242346e-05 2.6484222 1338142.6 1.3257432 1.3225453
# 4000 1.7292298e-06 1.7092635e-06 0.19966266 64520.023 0.10024736 0.099408835
# 5000 7.3818765e-06 7.3637502e-06 0.18126133 354206.03 0.091284886 0.08994103
# 6000 1.6844332e-06 1.6702421e-06 0.14191093 62174.844 0.07138259 0.07052212
# 7000 2.2905087e-06 2.2712318e-06 0.19276993 71303.47 0.09668039 0.09608241
# 8000 4.6865084e-06 4.6362998e-06 0.5020847 341132.44 0.25180542 0.25024512
# 9000 5.542896e-06 5.506193e-06 0.36703086 232985.0 0.18429767 0.1827099
# 10000 1.6550832e-06 1.6399702e-06 0.151131 62012.88 0.07601751 0.075107306
# 11000 3.859871e-06 3.8474896e-06 0.123816036 182911.06 0.062326625 0.06147112
# 12000 7.2705798e-06 7.1943177e-06 0.7626185 182410.25 0.3818381 0.38076213
# 13000 3.7726818e-06 3.7573889e-06 0.15293035 118879.33 0.0770298 0.07588866
# 14000 5.0101203e-06 4.9856244e-06 0.2449591 354074.1 0.12294126 0.12198243
# 15000 1.6167604e-06 1.5959473e-06 0.2081314 61578.62 0.10444497 0.10368027
# 16000 1.6108515e-06 1.597763e-06 0.13088544 60016.06 0.06582386 0.06505557
# 17000 2.7810396e-05 2.7621136e-05 1.8925965 935999.25 0.9453841 0.9471189
# 18000 3.5649014e-06 3.5519806e-06 0.12920728 75810.12 0.06503626 0.06416345
# 19000 1.56881e-06 1.5559589e-06 0.1285111 55000.883 0.06460091 0.0639047
# 20000 2.328142e-06 2.3144316e-06 0.1371032 74331.35 0.06878726 0.068308495
# 21000 1.578085e-06 1.5598172e-06 0.1826775 55488.45 0.091672786 0.09099918
# 22000 1.6861774e-06 1.6716599e-06 0.14517489 81023.09 0.0728391 0.07232769
# 23000 3.7400882e-06 3.7227646e-06 0.17323622 162223.11 0.08694053 0.08627948
# 24000 2.3527728e-06 2.3294137e-06 0.23359075 451893.62 0.117338724 0.11620685
# 25000 2.7796546e-06 2.760057e-06 0.19597581 208321.9 0.09867182 0.097283155
# 26000 1.5394835e-06 1.5147035e-06 0.2477994 57224.562 0.124196954 0.12359672
# 27000 1.5588952e-06 1.5447499e-06 0.1414526 55617.68 0.070926584 0.07052045
# 28000 9.5432406e-05 9.536969e-05 0.62721944 2437349.0 0.31479275 0.31218293
# 29000 2.2591335e-06 2.2367376e-06 0.22395933 74313.92 0.11208722 0.11186468
# 30000 1.5344355e-06 1.5061573e-06 0.28278148 54551.355 0.14162059 0.14115544
# 31000 2.1986658e-05 2.191852e-05 0.68138397 249637.38 0.34057474 0.34078428
# 32000 4.5166357e-06 4.504647e-06 0.11988414 188849.8 0.059939306 0.05992595
# 33000 2.6325715e-06 2.5926108e-06 0.39960784 488659.62 0.19940656 0.20015241
# 34000 7.233517e-06 7.1517893e-06 0.81727684 743688.06 0.40860483 0.40859768
# 35000 8.910667e-06 8.895364e-06 0.15303412 423455.53 0.07658717 0.076404594
# 36000 1.5775931e-06 1.5651001e-06 0.124930814 51350.844 0.06265299 0.062272687
# 37000 2.9513185e-06 2.932716e-06 0.18602672 262280.72 0.09320403 0.09279647
# 38000 3.885366e-06 3.8597004e-06 0.25665677 378543.88 0.12834924 0.12826969
# 39000 6.995026e-06 6.981367e-06 0.13659418 249782.25 0.06860309 0.0679661
# 40000 1.3425925e-05 1.3386331e-05 0.39594355 930972.44 0.19824514 0.19760531
# 41000 1.4000977e-06 1.3830874e-06 0.1701045 52393.31 0.085188895 0.08491037
# 42000 1.3859994e-06 1.3755107e-06 0.10488725 47141.066 0.05253102 0.052351512
# 43000 1.4532839e-06 1.4414593e-06 0.118245885 46478.74 0.059089627 0.059151612
# 44000 1.0165117e-05 1.01268315e-05 0.38285014 506169.78 0.19184744 0.19095208
# 45000 4.039803e-06 4.027288e-06 0.12515026 87862.59 0.062840074 0.0623014
# 46000 7.212544e-05 7.127541e-05 8.500269 14886236.0 4.2499113 4.248869
# 47000 1.3280157e-06 1.3151672e-06 0.12848577 43740.848 0.06433542 0.06414597
# 48000 1.3735427e-06 1.3640055e-06 0.09537216 48654.86 0.047768857 0.04759844
# 49000 1.5609974e-06 1.5496345e-06 0.113629356 53975.76 0.056764685 0.05685927
# 50000 3.9083305e-05 3.889746e-05 1.8584704 240182.77 0.93087655 0.9275699
# 51000 3.0543244e-05 3.052072e-05 0.22523543 656913.75 0.11296901 0.11220074
# 52000 1.8185237e-05 1.8131026e-05 0.54211164 697924.75 0.27368322 0.26835862
# 53000 1.6816385e-06 1.6727598e-06 0.08878661 102851.12 0.04439147 0.044384856
# 54000 1.5149719e-06 1.5061228e-06 0.08849126 53141.652 0.04424346 0.044242483
# 55000 1.3739538e-06 1.3652245e-06 0.08729213 60183.723 0.043619942 0.043666165
# 56000 3.5536093e-06 3.5396704e-06 0.13938977 63375.71 0.06997437 0.06940906
# 57000 1.2657221e-06 1.2424721e-06 0.23249944 49683.727 0.116265565 0.1162289
# 58000 8.675034e-06 8.651173e-06 0.23861197 197654.81 0.119300775 0.11929142
# 59000 1.847086e-05 1.8451548e-05 0.19312668 395265.5 0.09688134 0.09620581
# 60000 1.594481e-06 1.584779e-06 0.097019106 44634.867 0.04856602 0.04844862
# 61000 2.2231873e-06 2.2136246e-06 0.09562555 74911.36 0.04774352 0.047874533
# 62000 1.2580753e-05 1.2438931e-05 1.4182173 372241.84 0.7084344 0.70974565
# 63000 7.4962927e-06 7.474756e-06 0.21536851 347585.0 0.10788457 0.107449174
# 64000 4.734854e-06 4.702924e-06 0.31930128 716086.9 0.15933098 0.15989868
# 65000 1.1676888e-06 1.1587367e-06 0.089520276 40166.3 0.04467762 0.04483864
# 66000 1.2693489e-06 1.258267e-06 0.110818595 45096.844 0.055188227 0.055625856
# 67000 1.5807062e-06 1.5715e-06 0.09206301 40162.188 0.045887314 0.046171676
# 68000 1.5025216e-06 1.4904529e-06 0.12068786 194119.58 0.060381863 0.06028658
# 69000 1.698336e-05 1.694089e-05 0.42470545 647873.7 0.2117896 0.21285108
# 70000 1.1180913e-06 1.109407e-06 0.08684316 37721.367 0.043306936 0.043532453
# 71000 3.5367975e-06 3.5251574e-06 0.1164023 168345.44 0.058141064 0.0582444
# 72000 1.2637795e-06 1.2554301e-06 0.0834939 44257.168 0.041621886 0.04186759
# 73000 2.4384675e-05 2.4332112e-05 0.525639 1246676.0 0.26356372 0.2619506
# 74000 4.4312114e-06 4.390992e-06 0.40219283 70585.41 0.20032836 0.20185742
# 75000 1.0675025e-06 1.0588776e-06 0.08624894 34314.926 0.04296639 0.043279123
# 76000 2.213322e-05 2.2111048e-05 0.22171056 502360.66 0.11095137 0.11070896
# 77000 8.20206e-05 8.18928e-05 1.2779622 3218796.8 0.63826776 0.63937265
# 78000 1.3986763e-06 1.3900226e-06 0.08653778 38229.207 0.04310182 0.04343213
# 79000 2.462573e-06 2.4379044e-06 0.24668661 119938.234 0.12291244 0.123762175
# 80000 1.0350207e-06 1.0232577e-06 0.117629915 33745.945 0.0586619 0.058964636
# 81000 1.0107208e-06 1.003015e-06 0.07705834 33197.285 0.03834702 0.038707998
# 82000 1.4611237e-05 1.45712775e-05 0.3995915 605486.56 0.19913541 0.20039554
# 83000 2.0290756e-05 2.0271402e-05 0.19353677 612292.5 0.09634397 0.09713157
# 84000 1.4502521e-06 1.4408703e-06 0.09381772 51894.777 0.046701837 0.04711069
# 85000 9.83749e-07 9.761354e-07 0.07613639 32878.902 0.037844274 0.038288824
# 86000 9.777225e-07 9.622626e-07 0.1545988 32142.666 0.07711763 0.07747797
# 87000 9.5193104e-07 9.4371694e-07 0.08214086 29948.248 0.04088664 0.041251224
# 88000 2.0647702e-05 2.0628173e-05 0.19528097 623782.25 0.0972134 0.0980052
# 89000 3.1164543e-06 3.1088882e-06 0.075661786 132345.25 0.037697423 0.037951127
# 90000 1.5173287e-06 1.5027617e-06 0.14566961 75319.4 0.07252912 0.07313295
# 91000 2.7451983e-05 2.7433209e-05 0.18772942 251213.02 0.09322384 0.09448045
# 92000 9.1730874e-07 9.067985e-07 0.10510223 28772.748 0.05233928 0.05276008
# 93000 8.971321e-07 8.89904e-07 0.07228109 28498.576 0.035897095 0.036381144
# 94000 9.702036e-06 9.689835e-06 0.12201324 257296.52 0.06087434 0.061113175
# 95000 1.6242467e-06 1.616361e-06 0.0788568 29991.377 0.039119337 0.039734468
# 96000 1.5331356e-06 1.5243156e-06 0.08819943 45567.867 0.04371965 0.044475224
# 97000 1.7372479e-06 1.7287283e-06 0.08519567 141848.56 0.042363785 0.042817697
# 98000 8.654338e-07 8.48758e-07 0.16675767 27048.27 0.08320206 0.083552904
# 99000 8.380796e-07 8.3119915e-07 0.068804145 25112.947 0.03418371 0.034617927
# 100000 1.0497595e-06 1.0428389e-06 0.06920586 32236.156 0.03439642 0.034806214
# 101000 4.190832e-05 4.187881e-05 0.2950801 2721017.5 0.14719614 0.14761186
# 102000 9.1738093e-07 9.1134234e-07 0.06038597 34942.125 0.029961757 0.030420717
# 103000 7.961628e-07 7.884819e-07 0.076808974 23446.338 0.038192753 0.038613882
# 104000 7.913855e-07 7.8513295e-07 0.0625257 22884.055 0.03103108 0.03149233
# 105000 2.8077493e-05 2.8055416e-05 0.22076572 1039925.94 0.11058414 0.11007759
# 106000 8.5163106e-07 8.4465233e-07 0.0697874 25629.65 0.034534357 0.035250474
# 107000 4.8793913e-06 4.860488e-06 0.18903546 97260.51 0.094678335 0.0943474
# 108000 8.0445e-07 7.8480736e-07 0.1964263 25110.346 0.09804147 0.09838232
# 109000 7.4067157e-07 7.3433534e-07 0.06336197 22294.514 0.03147984 0.031879906
# 110000 1.2512298e-06 1.2449509e-06 0.062788986 42556.016 0.031209094 0.03157564
# 111000 7.632313e-07 7.5734397e-07 0.058873534 21460.102 0.029172635 0.029698752
# 112000 1.5836513e-06 1.5771366e-06 0.06514727 53731.086 0.03232939 0.03281251
# 113000 2.7284075e-06 2.7212195e-06 0.07188073 64177.348 0.035718083 0.036156222
# 114000 7.04418e-07 6.94269e-07 0.101490274 19108.066 0.05056658 0.050921783
# 115000 6.875575e-07 6.823222e-07 0.05235252 18093.934 0.025949977 0.026400736
# 116000 7.1860336e-07 7.133911e-07 0.052122362 18683.84 0.025844814 0.026275681
# 117000 6.8969475e-06 6.8371455e-06 0.5980189 447491.25 0.2989068 0.2990673
# 118000 2.0931332e-06 2.0804416e-06 0.1269164 219412.81 0.063025355 0.0638691
# 119000 7.809395e-07 7.5884464e-07 0.22094887 20855.475 0.11027949 0.110667296
# 120000 6.788443e-07 6.661555e-07 0.12688833 18019.803 0.06320656 0.06367996
# 121000 6.8585297e-07 6.7861004e-07 0.0724291 18282.008 0.035964735 0.036462534
# 122000 8.41424e-07 8.3485213e-07 0.06571883 32230.65 0.032770272 0.032945335
# 123000 3.8862327e-06 3.868679e-06 0.17553626 228547.33 0.08803846 0.08747494
# 124000 5.2853e-05 5.2810436e-05 0.4256503 2049208.1 0.21190597 0.21353939
# 125000 1.8647207e-06 1.856206e-06 0.08514732 24156.15 0.04198332 0.043161586
# 126000 8.446065e-07 8.3735375e-07 0.07252772 19488.82 0.03584729 0.036678478
# 127000 6.302347e-07 6.2165265e-07 0.08582056 17283.44 0.042559747 0.043259088
# 128000 6.070437e-07 6.0181543e-07 0.052282818 16521.406 0.025814611 0.026466552
# 129000 6.527541e-07 6.469993e-07 0.05754818 17600.252 0.028335843 0.029210575
# 130000 6.0106044e-07 5.957919e-07 0.05268515 17318.414 0.025946645 0.026736772
# 131000 1.4102447e-06 1.4052413e-06 0.05003517 92976.84 0.024585478 0.025440397
# 132000 9.605074e-06 9.557237e-06 0.47837263 219992.62 0.2380659 0.24028473
# 133000 1.3089782e-06 1.301515e-06 0.074631736 89041.9 0.036742765 0.03788007
# 134000 3.818126e-06 3.8126047e-06 0.055214655 36413.7 0.027027523 0.02818349
# 135000 1.7326167e-05 1.7231692e-05 0.9447534 432690.94 0.46915945 0.4755507
# 136000 5.6245005e-07 5.57367e-07 0.05083066 16015.646 0.024976531 0.025852526
# 137000 9.086338e-07 9.035604e-07 0.050733767 24944.494 0.02490853 0.025822742
# 138000 5.5102475e-07 5.4014725e-07 0.108774856 17544.115 0.054049775 0.05472333
# 139000 5.369086e-07 5.3208083e-07 0.0482774 16102.993 0.02371772 0.02455807
# 140000 1.3366803e-05 1.3335424e-05 0.3137892 104402.58 0.15616806 0.15761067
# 141000 1.5587693e-05 1.5571713e-05 0.15979862 77272.43 0.07967664 0.080114245
# 142000 2.3039206e-06 2.293494e-06 0.104266666 55210.14 0.05148541 0.052775733
# 143000 3.3037247e-06 3.2974228e-06 0.06301847 201524.58 0.03096066 0.032037653
# 144000 8.662829e-07 8.6091114e-07 0.053717602 34730.535 0.026417527 0.0272966
# 145000 4.3968193e-05 4.3873843e-05 0.94349504 611814.9 0.4728342 0.47059968
# 146000 6.3217993e-07 6.2228054e-07 0.0989939 27353.117 0.048978362 0.0500128
# 147000 6.2182426e-07 6.166657e-07 0.051585644 20151.139 0.025359722 0.02622391
# 148000 7.571886e-07 7.495115e-07 0.07677075 25345.428 0.037672523 0.0390957
# 149000 4.9879696e-07 4.9350456e-07 0.052923806 16416.043 0.02593116 0.026991002
# 150000 1.5575373e-05 1.5567077e-05 0.08296169 170709.5 0.041064646 0.041879978
# 151000 9.607191e-07 9.524167e-07 0.08302429 82808.65 0.04122915 0.04178686
# 152000 4.827981e-07 4.759168e-07 0.06881291 15587.509 0.033913463 0.034897886
# 153000 4.971487e-07 4.923475e-07 0.04801143 16020.163 0.023482021 0.024527805
# 154000 8.8879926e-07 8.8338055e-07 0.054186873 50451.312 0.026694287 0.02748754
# 155000 1.2999761e-06 1.2942913e-06 0.05684781 36662.812 0.027989948 0.028854199
# 156000 3.0408304e-05 3.0381323e-05 0.26981178 663300.8 0.13401656 0.1357289
# 157000 4.930573e-07 4.8796636e-07 0.050909713 15982.938 0.024864145 0.026043972
# 158000 4.6798607e-07 4.6045093e-07 0.07535128 16840.377 0.037163977 0.03818562
# 159000 4.523037e-07 4.4713522e-07 0.05168497 16756.293 0.025277644 0.026405646
# 160000 1.4187604e-05 1.4162696e-05 0.24908581 247287.98 0.12319007 0.12587102
# 161000 9.216557e-07 9.161852e-07 0.05470556 29466.87 0.026839534 0.027863082
# 162000 5.9889237e-07 5.9375697e-07 0.051354058 16000.987 0.025075832 0.026276624
# 163000 7.4829785e-07 7.3842045e-07 0.09877378 31648.375 0.048556417 0.05021419
# 164000 6.1147006e-07 5.950806e-07 0.16389413 50228.51 0.08159101 0.0822981
# 165000 4.3619616e-07 4.312446e-07 0.049515657 16518.828 0.02413995 0.025374055
# 166000 5.173659e-07 5.1187766e-07 0.054882478 24610.127 0.026734523 0.028145494
# 167000 4.7099257e-07 4.6581826e-07 0.051743113 20629.123 0.025154306 0.026586741
# 168000 4.3715264e-07 4.3221243e-07 0.049401946 16035.868 0.024049778 0.025350563
# 169000 1.1523601e-06 1.1474115e-06 0.049487025 132483.22 0.023956833 0.025516942
# 170000 4.3616575e-07 4.2758654e-07 0.085792154 16323.4375 0.042263806 0.043526717
# 171000 4.87639e-07 4.8286546e-07 0.047735408 17311.107 0.023198238 0.024535442
# 172000 1.3804495e-05 1.3738691e-05 0.65804154 56742.277 0.32810634 0.32992953
# 173000 8.265509e-07 8.207874e-07 0.057634853 22442.81 0.028014744 0.029617867
# 174000 5.7135117e-07 5.644646e-07 0.068866 17875.516 0.033539876 0.03532433
# 175000 3.1608248e-05 3.1580144e-05 0.2810505 908530.25 0.13928722 0.14167242
# 176000 4.1473535e-07 4.0860405e-07 0.061313108 16047.631 0.030097906 0.031213595
# 177000 7.027432e-06 7.013638e-06 0.13793981 463809.06 0.06821338 0.06968005
# 178000 1.2903292e-06 1.2815739e-06 0.087553404 137423.94 0.043306366 0.044233296
# 179000 2.575412e-06 2.5685015e-06 0.069105566 19354.914 0.03361854 0.03548509
# 180000 2.6840414e-06 2.6647044e-06 0.19336973 122436.01 0.09618277 0.09717472
# 181000 1.2256997e-06 1.208015e-06 0.17684832 42933.668 0.08728961 0.089554414
# 182000 3.9942904e-07 3.9399274e-07 0.054362945 15375.74 0.026541471 0.027819939
# 183000 3.9321048e-07 3.8865974e-07 0.04550729 15095.106 0.02208647 0.023419313
# 184000 4.0105303e-07 3.964438e-07 0.04609234 15630.643 0.022369193 0.023721583
# 185000 4.7550807e-07 4.709429e-07 0.04565168 20638.338 0.022241466 0.023408152
# 186000 3.006355e-05 3.0038784e-05 0.2476553 1432551.2 0.12361856 0.12389349
# 187000 4.0051987e-07 3.9131294e-07 0.09206924 16296.806 0.04546896 0.04659865
# 188000 6.255316e-07 6.192272e-07 0.063043855 32744.738 0.030549845 0.032490738
# 189000 3.805142e-07 3.7567298e-07 0.04841199 17405.2 0.02353883 0.024871422
# 190000 5.63501e-07 5.5795886e-07 0.055421375 30694.168 0.02702243 0.028395874
# 191000 5.9082954e-06 5.880723e-06 0.27572116 782969.3 0.13802336 0.13761951
# 192000 1.90328e-06 1.8979871e-06 0.05292899 99838.21 0.025515066 0.02740394
# 193000 5.0602756e-07 4.914024e-07 0.14625207 24559.373 0.07259317 0.07365645
# 194000 3.8678024e-07 3.812544e-07 0.055258304 16169.943 0.026959918 0.02829677
# 195000 1.7455745e-06 1.7258781e-06 0.19696473 84817.78 0.098092236 0.09886401
# 196000 1.2331438e-05 1.2195809e-05 1.3562849 290797.56 0.67971116 0.67654455
# 197000 2.311306e-06 2.2992658e-06 0.120400466 283439.7 0.059494857 0.060877264
# 198000 3.792754e-07 3.7482218e-07 0.04453221 15730.429 0.02153818 0.022992458
# 199000 1.0438905e-06 1.0394956e-06 0.04394886 70098.74 0.021180559 0.022761289
# min total loss:  3.792754e-07

# %%
model.restore()
u_pred = model.call(tf.constant(t_test, tf.float32)).numpy()

# %%
# plt.plot(t_test * TIM, (u_pred[:, 14] * NDM[14] * scale[14] + u_pred[:, 16] * NDM[16] * scale[16]) * 1e-9, '--', label='Model(No Inh)')
# plt.plot(t_train * TIM, (u_train[:, 14] * NDM[14] * scale[14] + u_train[:, 16] * NDM[16] * scale[16]) * 1e-9, label='Model(No Inh)')
# plt.plot(t_exp_1, u_exp_1, 'bo', markerfacecolor='w', label='Exp')
# plt.show()

# %%
plt.plot(t_test * TIM, u_test[:, 10], label='u10')
plt.plot(t_test * TIM, u_pred[:, 10], '--', label='u10')
plt.plot(t_train * TIM, u_train[:, 10], '.', label='u10')
plt.plot(t_test * TIM, u_test[:, 31], label='u31')
plt.plot(t_test * TIM, u_pred[:, 31], '--', label='u31')
plt.plot(t_train * TIM, u_train[:, 31], '.', label='u31')
plt.plot(t_test * TIM, u_test[:, 32], label='u32')
plt.plot(t_test * TIM, u_pred[:, 32], '--', label='u32')
plt.plot(t_train * TIM, u_train[:, 32], '.', label='u32')
plt.legend()
plt.show()

# %%
j = 10
plt.plot(t_test, u_pred[:, j] * NDM[j] * scale[j] * 1e-9, '--')
plt.plot(t_train, u_train[:, j] * NDM[j] * scale[j] * 1e-9, ".")
plt.show()

# %%
# plt.plot(t_test * TIM, u_pred[:, 16] * NDM[16] * scale[16] * 1e-9, '--')
# plt.plot(t_train * TIM, u_train[:, 16] * NDM[16] * scale[16] * 1e-9)
# plt.show()

# %%
# h_10_TPplus = 4.381
# h_10_TPminus = 5.293 * 1e-8
# h_2 = 1.79 * 1e-4
print("h_10_TPplus:", tf.math.exp(model.log_h_10_TPplus).numpy())
# print("h_10_TPminus:", model.h_10_TPminus.numpy())
# print("h_2:", model.h_2.numpy())
# Out:
# h_10_TPplus: 4.299554

# %%
model.log_h_10_TPplus
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.92803544>
