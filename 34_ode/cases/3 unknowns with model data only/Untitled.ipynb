# %%
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt

# %%
reference = sio.loadmat("../../data/Susree_model/reference.mat")
data = sio.loadmat("../../data/Susree_model/data2.mat")
t_ref = reference["t"]
Y_ref = reference["Y"]

t = data["t"]
Y = data["Y"]

# %%
plt.plot(t, Y)
plt.show()

# %%
plt.plot(t_ref, Y_ref)
plt.show()

# %%
plt.plot(t_ref, Y_ref[:, 31])
plt.plot(t, Y[:, 31], "--")
