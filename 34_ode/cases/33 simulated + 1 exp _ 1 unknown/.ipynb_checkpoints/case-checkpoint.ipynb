# %% [markdown]
# ## case 3:
# TF = 25 pM, original initial conditions
# ## Given:
# model data of 33 species (except species 16)
# experiment data of 1 species (species 16)
# ODE with 1 unknown: h_2
# ## Target to:
# fit experiment data
# infer 1 unknown
# (expect that species 16 solved by ode solver with infered unknowns fit the experiment data)

# %%
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
import tensorflow as tf

import models

# %%
data = sio.loadmat("./data/data_case_3.mat")
t_test = data["t"]
u_test = data["Y"] # scaling?

#name_list = ['TF','VII', 'TF:VII', 'VIIa', 'TF:VIIa', 'IX', 'IXa', 'IXm', 'IXam',
#'X', 'Xa', 'Xm', 'Xam', 'II', 'IIa', 'IIm', 'IIam', 'PL', 'AP', 'VIII', 'VIIIa', 'VIIIm',
#'VIIIam', 'VIIIam:IXam', 'V', 'Va', 'Vm', 'Vam', 'Xam:Vam', 'I', 'Ia', 'TFPI', 'Xa:TFPI', 'ATIII']

TIM = 1800
NDM = [0.025, 10.0, 0.005, 10.0, 0.005, 90.0, 90.0, 10.0, 10.0, 170.0,
       170.0, 10.0, 10.0, 1400.0, 1400.0, 10.0, 10.0, 10.0, 10.0,
       0.7, 0.7, 0.7, 0.7, 0.7, 20.0, 20.0, 10.0, 10.0, 10.0, 7000.0,
       7000.0, 2.5, 2.5, 3400.0] #nM

exp_data = np.loadtxt("./data/exp_data_case_3.dat").T
t_exp = exp_data[0].reshape([-1, 1])
u_exp = exp_data[1].reshape([-1, 1])

plt.plot(t_test * TIM, (u_test[:, 14] * NDM[14] + u_test[:, 16] * NDM[16]) * 1e-9, 'b', label='Model(No Inh)')
plt.plot(t_exp, u_exp, 'bo', markerfacecolor='w', label='Exp')
plt.show()

# %%
plt.plot(t_test * TIM, u_test)
plt.show()

# %%
scale = np.array(
    [1, 1, 5, 0.5, 0.1, 1, 0.0000002, 10, 0.001, 0.005, \
     0.001, 10, 2, 0.01, 0.01, 100, 100, 1, 1, 1, \
    0.0001, 1, 1, 0.01, 1, 0.0001, 1, 1, 1, 1, \
    1, 1, 1, 1]
).reshape([-1])

u_test = u_test / scale

plt.plot(t_test[100:] * TIM, u_test[100:, :])
plt.show()

# %%
# u_test[:, 16] * NDM[16] * scale[16] * 1e-9 = u_exp * scale_exp
# u_test[:, 16] * 10.0 * 100 * 1e-9 = u_exp * scale_exp
# u_test[:, 16] * 1e-6 = u_exp * scale_exp
scale_exp = 1e-6
u_exp = u_exp / scale_exp

# %%
plt.plot(t_test * TIM, u_test[:, 16], 'b', label='Model(No Inh)')
plt.plot(t_exp, u_exp, 'bo', markerfacecolor='w', label='Exp')
plt.show()

# %%
t_train_model = t_test[200:][::20] # discard first 200 fluctuant points
u_train_model = u_test[200:][::20]
t_train_exp = t_exp / TIM
u_train_exp = u_exp
f_train = np.zeros_like(u_train_model)

model = models.PINN(TIM, NDM, scale, eps=1e-6)

# %%
# loss = model.train(t_train, f_train, t_train, u_train, eps=1e-7, niter=400000)
loss = model.train(t_train_model, f_train, t_train_model, u_train_model, t_train_exp, u_train_exp, eps=1e-9, niter=50000)
# print total loss, data loss, ode loss, eq10_loss, eq14_loss, eq31_loss, eq32_loss, eq33_loss
# Out:
# WARNING:tensorflow:Gradients do not exist for variables ['Variable:0', 'Variable:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['Variable:0', 'Variable:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 2023-12-13 17:01:01.327824: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
#
# 36000 0.00015727684 0.00013999133 17285.51 270310980000.0 1728551000.0 5323.8086 5320.9565 1.00877
# 37000 0.0001570214 0.00013966726 17354.14 272147760000.0 1735414100.0 5235.9917 5238.2617 1.0260389
# 38000 0.0001799358 0.00016265838 17277.412 270770520000.0 1727741200.0 5060.203 5066.1553 1.0508751
# 39000 0.00022088372 0.00020349723 17386.502 267209340000.0 1738650200.0 4570.711 4579.73 1.062202
# 40000 0.000210003 0.00019267797 17325.03 267861720000.0 1732503000.0 4444.786 4454.846 1.034057
# 41000 0.00016300181 0.0001456816 17320.209 270063620000.0 1732021000.0 4345.8164 4356.071 1.0842041
# 42000 0.00025179263 0.00023467536 17117.264 266451550000.0 1711726500.0 4393.8135 4403.9146 1.1102839
# 43000 0.00018295413 0.00016569378 17260.342 264187400000.0 1726034200.0 4101.907 4112.516 1.0927966
# 44000 0.00018933429 0.0001719509 17383.385 264270700000.0 1738338600.0 4021.006 4030.4448 1.1236593
# 45000 0.00019633709 0.00017904236 17294.727 256559190000.0 1729472600.0 3507.4421 3517.5942 1.1056521
# 46000 0.0005148625 0.00049719214 17670.324 255281270000.0 1767032400.0 3367.1594 3379.061 1.1216891
# 47000 0.0005113427 0.00049421797 17124.74 255805010000.0 1712474100.0 3013.0024 3024.6787 1.1103582
# 48000 0.00014860244 0.00013132211 17280.322 251384220000.0 1728032300.0 3001.5837 3012.8462 1.1301023
# 49000 0.0001469742 0.00012964052 17333.672 248643200000.0 1733367300.0 2717.4768 2728.823 1.1305898
# min total loss:  0.0001469742

# %%
model.restore()
u_pred = model.call(tf.constant(t_test, tf.float32)).numpy()

# %%
# plt.plot(t_test * TIM, u_test[:, 10], label='u10')
# plt.plot(t_test * TIM, u_pred[:, 10], '--', label='u10')
# plt.plot(t_train_model * TIM, u_train_model[:, 10], '.', label='u10')
# plt.plot(t_test * TIM, u_test[:, 13], label='u13')
# plt.plot(t_test * TIM, u_pred[:, 13], '--', label='u13')
# plt.plot(t_train_model * TIM, u_train_model[:, 13], '.', label='u13')
# plt.plot(t_test * TIM, u_test[:, 14], label='u14')
# plt.plot(t_test * TIM, u_pred[:, 14], '--', label='u14')
# plt.plot(t_train_model * TIM, u_train_model[:, 14], '.', label='u14')
# plt.plot(t_test * TIM, u_test[:, 16], label='u16')
# plt.plot(t_test * TIM, u_pred[:, 16], '--', label='u16')
# plt.plot(t_train_exp * TIM, u_train_exp, '.', label='u16')
plt.plot(t_test * TIM, u_test[:, 18], label='u18')
plt.plot(t_test * TIM, u_pred[:, 18], '--', label='u18')
plt.plot(t_train_model * TIM, u_train_model[:, 18], '.', label='u18')
plt.plot(t_test * TIM, u_pred[:, 33], '--', label='u33')
plt.plot(t_train_model * TIM, u_train_model[:, 33], '.', label='u33')
plt.legend()
plt.show()

# %%
j = 16
plt.plot(t_test, u_pred[:, j] * NDM[j] * scale[j] * 1e-9, '--')
# plt.plot(t_train_model, u_train_model[:, j] * NDM[j] * scale[j] * 1e-9, ".")
plt.plot(t_train_exp, u_train_exp * scale_exp, "o")
plt.show()

# %%
# References:
# h_10_TPplus = 4.381
# h_10_TPminus = 5.293 * 1e-8
# h_2 = 1.79 * 1e-4
print("h_10_TPplus:", tf.math.exp(model.log_h_10_TPplus).numpy())
print("h_10_TPminus:",  tf.math.exp(model.log_h_10_TPminus).numpy())
print("h_2:", tf.math.exp(model.log_h_2).numpy())
# Out:
# h_10_TPplus: 1.0
# h_10_TPminus: 1.0
# h_2: 7.096138e-06
