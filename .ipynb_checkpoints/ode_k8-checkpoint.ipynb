# %%
# known: all data + parameters except k8
# unknown: k8

# %%
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt

import tensorflow as tf
import models_tf as models

# %%
data = sio.loadmat("solution.mat")
c0 = data["IC"]
t = data["t"]
c_ref = data["y"]

t_train = t

scale = np.array(
    [10, 1, 100, 100, 0.001, 10, 0.1, 1000]
).reshape([-1])
c_ref = c_ref / scale
c0 = c0 / scale

# %%
np.max(data["y"], axis=0)
# Out:
# array([2.59399416e+01, 3.54133207e+00, 8.57923329e+02, 1.00000000e+03,
#        1.14212936e-03, 3.84436903e+01, 8.68846177e-01, 2.16754273e+03])

# %%
model = models.PINN(
    c0=c0,
    output_dim=8,
    scale=scale,
    units=100, 
    activation=tf.tanh,
    eps=1e-4,
)

# %%
t_ode = t_train[::10]
t_u = t_train
u = c_ref
loss, data_loss, ode_loss = model.train(t_ode, t_u, u, niter=120000)
# Out:
# WARNING:tensorflow:Gradients do not exist for variables ['log_k1:0', 'log_k_apc:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['log_k1:0', 'log_k_apc:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['log_k1:0', 'log_k_apc:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['log_k1:0', 'log_k_apc:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 0 3961912.5
# 1000 10.731768
# 2000 6.4078484
# 3000 3.85431
# 4000 2.8394384
# 5000 1.8711206
# 6000 63613.562
# 7000 1.3913667
# 8000 1.4856336
# 9000 6.880988
# 10000 1.354647
# 11000 1.3286986
# 12000 2.3390546
# 13000 1.8890722
# 14000 1.7347269
# 15000 1.6160039
# 16000 1.5347148
# 17000 1.4265888
# 18000 1.354969
# 19000 1.3194667
# 20000 1.2841163
# 21000 1.2255408
# 22000 1844.1769
# 23000 1.0956851
# 24000 1.0663356
# 25000 1.0403202
# 26000 1.0356033
# 27000 1.0149982
# 28000 1.0447677
# 29000 1.0029072
# 30000 0.98514456
# 31000 0.9657476
# 32000 0.9776
# 33000 0.9417267
# 34000 0.9108666
# 35000 0.8908987
# 36000 0.8278442
# 37000 0.76825994
# 38000 0.6779422
# 39000 0.6091243
# 40000 0.57184917
# 41000 0.5342627
# 42000 0.5135497
# 43000 0.49603623
# 44000 1.9609841
# 45000 0.46881136
# 46000 0.48327973
# 47000 0.44913018
# 48000 9.353254
# 49000 0.44293076
# 50000 0.43551752
# 51000 0.43400094
# 52000 0.43128273
# 53000 0.42930326
# 54000 0.4823582
# 55000 0.42587253
# 56000 0.42693654
# 57000 0.4244877
# 58000 0.46710607
# 59000 0.43090692
# 60000 0.42041528
# 61000 0.41831648
# 62000 0.41624647
# 63000 0.3679613
# 64000 0.067984685
# 65000 0.020765234
# 66000 0.009799212
# 67000 0.0050597787
# 68000 0.0025955886
# 69000 0.0032677744
# 70000 0.00079041574
# 71000 0.00097019994
# 72000 0.00035237684
# 73000 0.000248383
# 74000 0.00027228205
# 75000 0.0019600436
# 76000 0.00036286085
# 77000 0.001321534
# 78000 6.654254e-05
# 79000 7.871336e-05
# 80000 0.0006587208
# 81000 0.00089507975
# 82000 0.00021322981
# 83000 8.8862624e-05
# 84000 0.00044528
# 85000 7.925324e-05
# 86000 0.00025319532
# 87000 7.660772e-05
# 88000 0.00032263412
# 89000 0.0007328869
# 90000 0.0012828675
# 91000 4.151878e-05
# 92000 5.5025972e-05
# 93000 0.0015478515
# 94000 6.647277e-05
# 95000 0.0016233074
# 96000 0.0027590464
# 97000 0.0004061588
# 98000 0.0017838926
# 99000 0.0007434234
# 100000 0.0026936915
# 101000 1.06788e-05
# 102000 0.00015519299
# 103000 0.0001898002
# 104000 2.4941752e-05
# 105000 8.826359e-05
# 106000 2.6673526e-05
# 107000 0.00019210223
# 108000 0.00017226263
# 109000 2.1407011e-05
# 110000 0.00022416523
# 111000 1.1784293e-05
# 112000 0.0015307338
# 113000 5.6280614e-06
# 114000 0.000311901
# 115000 0.0005799982
# 116000 0.00013237212
# 117000 1.6557267e-05
# 118000 6.584387e-06
# 119000 0.00014102906

# %%
model.restore()
c_pred = model.call(
    tf.constant(t_train, tf.float32),
)

# %%
L2 = np.sqrt(np.sum((c_pred - c_ref) ** 2, axis=0) / np.sum(c_ref ** 2, axis=0))

# %%
L2
# Out:
# array([0.00090217, 0.00153445, 0.00193475, 0.00054406, 0.00698403,
#        0.00124592, 0.00035616, 0.00138014])

# %%
print(tf.math.exp(model.log_k1))
# Out:
# tf.Tensor(1.0, shape=(), dtype=float32)

# %%
print(tf.math.exp(model.log_k_apc))
# Out:
# tf.Tensor(1.0, shape=(), dtype=float32)

# %%
print(tf.math.exp(model.log_k8))
# Out:
# tf.Tensor(1.0019238e-05, shape=(), dtype=float32)

# %%
j = 2
plt.figure(dpi=200)
plt.plot(t_train, c_ref[:, j], "-", label="reference")
# plt.plot(t_train, y_train, '.', label="train")
plt.plot(t_train, c_pred[:, j], "--", label="prediction")
# plt.legend()
plt.show()

# %%
plt.figure(dpi=200)
plt.plot(t_train, c_ref, "-", label="reference")
# plt.plot(t_train, y_train, '.', label="train")
plt.plot(t_train, c_pred, "--", label="prediction")
# plt.legend()
plt.show()

# %%
plt.figure(dpi=200)
plt.plot(np.log10(ode_loss)[::100], "-", label="ode_loss")
plt.plot(np.log10(data_loss)[::100], "-", label="data_loss")
# plt.plot(np.log(loss), "-", label="loss")
plt.xlabel('iterations/100')
plt.ylabel('log of loss')
plt.legend()
plt.show()
